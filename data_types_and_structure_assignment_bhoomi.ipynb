# %% [markdown]
#   1. what are data strctures.and why are they important ?
#          Data structure way of organizing and storing data so that it can be accessed and manuiplate
#           1 Efficieny choosing the right data structure can make your code faster and more memory-efficient.
#           2 organized data handling: they help store and maanage data in a logical and accessible way.
#           3 Ease of use: python built in data strctures simplify oding by providing built in functions and methods
#           4 Better problem solving: they allow programmers to solve complex programmers to solve complex problems more easily (e.g using a dictionary for fast lookups)
#           5 foundation for algorithms: many algorithms (like sorting,searching ,or garph traversal) rely on specfic data structure.
#
#   2.
#
#     3. what are the main difference between lists and tuples in python?
#             .f Mutability  mutable (can be changed)
#               syntax   defined using square brackets{}
#               methods  has more built in methods(e.g appened {emove{))
#               performance slower (more overhead due to mutability)
#               use case when data may change (e.g dynamic lists)
#               Memory usage  requires more memory
#       my_list ={1,2.3}
#        my_list,append(4)
#        print (my_list) #output " {1,2,3,4}
#         tuple
#          my_tuble = {1,2,3}
#          # my_tuple0} = 5 # this will raise a typeerror
#           print (my_tuple )# output  ;(1,2,3}
#
#       4.  describe how dictionaries store data?
#                 .f dicitionaries in programming (specifically in python and many other lanuages) store data using a key value pair strcture. here ,s breakdown of how they work and how they store under the hood.
#
#       5. why might you use a set instead of a list in python ?
#                 .f you might use a set insteads of a list in python for several key reasons, depending on your need,
#                numbers = {1,2,2,3,3,}
#                unique
#
#       6. what is a string in python, and how is it different from a list ?
#                .f  A string is a sequence of characters letters numbers symbols or spaces encloes in python.
#                  my_string = "hello"
#                   ypu can acesss indiviual characters using a index
#                   print(my_string[1] # output ;
#
#                   lists
#                    A list is a collection of items called elements which can be of any data type including strings numbers or even other lists.
#                     my_list = ['h', 'e', 'l', 'l', 'o',]
#                     print (my_list[1] # output: 'e'
#
#        7. How do tuples ensure data integrity in python?
#                .f  It means keeping your data safe, correct, and unchanged over time.
#               1. they can,t be changed
#                  once you create a tuple, you can,t add , remove, or change amy of its items without getting or error.
#                   colors = ("red", "green", "blue", )
#                   colors {0} = "yellow" # * type error !
#                   location _counts = (10,20):5, (15,30):7}
#
#         8. what is a hash table , and how does it relate to dictionaries in python?
#                   A hash table is a smart way to store key value pairs so you find anything suer fast usually in constant time
#                    1 you have an array (like a row of mailboxes)
#                    2 that numbers tells you which mail box (array slot) to use:
#                     index = hash (key) % array _size
#                    3 you store your value in that slot.
#
#         9. can list contain different data types in python?
#                   A list is a collection of items elclosed in square brackets ,like this:
#                   my_list = [10, "apple", 3.,4, true]
#                    here, 10 is an integer ,"apple" is a string 3.14 is a float and true is a boolen all in the same list.
#                   1. flexible data storage.
#                     you can mix numbers, text, truth vales, and even other lists or tuples in one list.
#                   2. Ease of use .
#                    No need to create separte lissts pr containers for each type .just put everything together!
#         10, Explain why strings are immutable in python?
#                 strings in python are immutable , which means once a string is created it cannot be changed let.s break down what this means in an easy way:
#                 1 Memory efficieny
#                  Python can recuse the same string in many places without copying it. beacuse it does,nt change, it ,s safe to share.
#                 2. Hashability
#                   immutable obejcts like strings get a fixed hash. this lets you use them reliably as keys in dictonaries or items in sts.
#                 3. Thread safety
#                   multiple threads can use the same string without worrying about someone accidentlty changing it.
#                 4. Simpler and fewer bugs
#                   since strings can,t change they,re easier to reason  about to less likely to be accidentally modified in code.
#                   s = "hello"
#                   s = s.upper () # "HELLO",
#                   upper ( ) returns a new string ,and s now refers to that.
#                    the original "hello" stays unchanged.
#
#        11. what advantages do dictionaries offer over lists for certain tasks?
#                  1. Super fast lookup by name
#                    with a dictinary , you can get a value by its key insatlty - no matter how many items there are (average time is 0 (1)
#                     if yo try to find a specfic value in a list, python might have to check every items oneby one
#                  2. Lookups by meaningful names not just positions.
#                     in dictionaries keys can be real names, numbers, or tuples anything immutable.
#                      lists only let you use simple inetger positions like my _list {3} which isn,t very discriptive,
#                  3. Ensure each key is unique
#                     A dictionary won,t let you have two identical keys it automatically keeps one clear value per key.
#                     A lsit lets you have duplicate values, which can lead to confusion.
#                  4. Easy to add, update , or remove by key
#                     you can quickly do things like
#                      gradest {" Alice "] = 95 , update
#                      gradest [ "bob" = 88, or delete del
#                      gradest ["Eve"].
#                      Doing these tasks in a list is possible but often awkared and slow since you must know where is the list the items is.
#                  5.  Great for mapping and real world data
#                      Dictionaries are perfect for things like phonebooks ( name -> number), settings  (setting _name -> value), or word counts (word -> grequency )
#
#             12. Describe a scenario where using a tuple would be preferable over a list?
#                     imagine you,re making a map and need to store fixed coordinates like gps locations of landmarks.
#                      point = (40,7128,-74,0060) #
#                      latitude and longitude of new york city
#                  1, Data shouldn,t change
#                   GPS coordinate won,t randomly change mid program. a tuple makes sure the values stay exactly as they were set no accidental edits.
#                  2. Memory and speed benefits
#                    tuples take slighty less emmory and are a bit faster to create compared to lists, which is helpful for large sets of data.
#                  3. Clear intention to others.
#                    setting (x,y) tells other programmers . "these are fixed values." with a list they might think it could change later.
#
#              13. How do sets handle duplicate values in python?
#                   A don,t allow duplicate values if yoyu try to add a value that ,s already in a set . it simply gets ignored the duplicate and keeps only one copy of each value.
#                      A set is like a basket where every item must be unique
#                       if you add the same  item again python says nope we already have that!" and ignores it.
#                       stes are created using curly braces {} or the set {} function.
#                        order doesn,t matter in sets. so you can,t control how items are stored.
#                        my_set = {1,2,2,3,3,4}
#                        print {my_set ) # output {1,2,3,4) {dupliactes 2 and 3 are removed.
#             14. How does the "in" keyword work differently for lists and dictionaries ?
#                        The in keyword in python behaves differently depending on whetever you,re working with lists or dictionaries because it checks for different things based on the data structure.
#                        my_list = [1,2,3,4]
#                         print 92 in( my_list) # true
#                          print (5 in my_list) # false
#                         my_dict = {'a' in my_dict ) # true
#                          print (1 in my_dict ) # false
#                           print (1 in my _dict . values ()} # true
#
#             15. can you modify the elements of a tuple? explain why or why not.
#                     Tuples are designed to be fixed collections of items . their immutability has benefits:
#                      1 performance : tuples are generally faster than lists for certain operations.
#                      2 hashability : since they,re immutable tuplescan be used as keys in dictionaries or elemnts in stes (if all their contents are also immuatble)
#                      3 data integrity : immutability helps ensure that data doesn,t get accidentlty changes.
#                      my_tuples = (1,2,3)
#                       my_tuples {0} = 10 #  * this will raise a type error
#                        type error : 'tuple' object does not support item assigenment.
#             16. what is a nested dictionary and give an example of its use case?
#                        A nested dictionary in python is a dictionary where the value of atleast one key is another dictionary.This allows you to represent structured or hierarchial data, like records,settings,or JSON-like objects.
#                        nested dictionaries are useful when you need to group related data under a common key. they are commonly used in - storing bdata about multiple entities.
#                         students = {
#                           " student }" {
#                             " bhoomi" " Alice"<
#                              " Age",   20.
#                              " grades " : { maths", 90.
#                              " science:"  85
#
#             17. Describe the name complexity of accessing elements in a dictionary ?
#                         Python dictionary has an average case time complexity of (1) this emans it takes constant time, regardless of the size of the dictionary.
#                  python dictionaries are implemented using hash tables. here ,s how it works:
#                   1 when you use a key (e'g  , my _dict {' key'] python computes its ahsh value.
#                   2 it uses thst hash to determine where the value is stored in memory .
#                   3 lookup is done in constant time without needing to search through all elements.
#             18. In what situations are lists preferred over dictionaries?
#                       dictionary access is very fast and is one of the reasons why dictionaries are widely used in python for key value storage let me know if you want a visual explanation of how hashing works under the food.
#                     1 Order matters: you need to maintain or rply on the order of elemnts.
#                     2 Data has no key value relationship : your,re working with simple, sequential data (e.g a list of names or numbers.)
#                     3 you need to iterate over items in order : useful for loops where order is important (e.g processing tasks step by step
#                     4 Memory efficiency is a concern : lists use less memory than dictionaries for storing simple values>
#                     5 index based access is needed : you want to acess items by position like my_ list[0}
#
#             19. why are dictionaries considered unodered and how does that affect data rerieval?
#                      Dictionaries preserve insertion order by language definition.
#                      however they are still logically unodered because the main purpose of a dictionary is fastt key based access not order,
#                      . yiu reterieve data by key not by postion index
#                      . you cannot rely on the order of items unless you,re using python which most modern environments do).
#             20.  Explain the difference between a list and a dictionary in terms of data reterival?
#                           Feature                            list
#                            How data is retrieved         By index (position )
#                            Accesss syntax                my_list{0}
#                             Time complexity             0 (1) for known
#                           Requires known             the position of the item
#                           order matters             yes, order is important and use preerved
#                            use case                    sequwntial , ordered data
#  Practiacl question

# %%
1. write a code to create a string with your name and print it?
...
...

name = "bhoomi"
print (name)
'''
'''
# Out:
#   File "/tmp/ipython-input-1-4128270655.py", line 2
#     """
#     ^
# SyntaxError: unterminated triple-quoted string literal (detected at line 4)

# %%
#
'''
2 write a code to find the length of the string "hello world"?
     text = " hello world"
      print (len(text))

'''
      print (len(text))
# Out:
#   File "/tmp/ipython-input-2-2296132290.py", line 2
#     '''
#     ^
# SyntaxError: incomplete input
